# %%
import PyPDF2
with open('proservartner_HR_example.pdf','rb') as f1:
    reader=PyPDF2.PdfReader(f1)
    total_pages=len(reader.pages)
    for page in reader.pages:
        print(page.extract_text())
# Out:
# HR
#
# Policy
#
# Document
#
# –
#
# Employee
#
# Guidelines
#
# Section
#
# 1:
#
# Leave
#
# Policies
#
# ●
#
# Sick
#
# Leave:
#
# All
#
# full-time
#
# employees
#
# are
#
# entitled
#
# to
#
# 12
#
# paid
#
# sick
#
# days
#
# per
#
# calendar
#
# year.
#
# ●
#
# Vacation
#
# Leave:
#
# Employees
#
# are
#
# granted
#
# 15
#
# vacation
#
# days
#
# per
#
# year,
#
# subject
#
# to
#
# prior
#
# managerial
#
# approval.
#
# ●
#
# Personal
#
# Leave:
#
# Up
#
# to
#
# 3
#
# personal
#
# days
#
# may
#
# be
#
# taken
#
# for
#
# emergencies
#
# or
#
# special
#
# occasions.
#
# Documentation
#
# may
#
# be
#
# required.
#
# Section
#
# 2:
#
# Work-from-Home
#
# Guidelines
#
# ●
#
# Eligibility:
#
# Employees
#
# who
#
# have
#
# completed
#
# at
#
# least
#
# 6
#
# months
#
# of
#
# service
#
# are
#
# eligible
#
# for
#
# remote
#
# work.
#
# ●
#
# Schedule:
#
# Remote
#
# work
#
# is
#
# permitted
#
# up
#
# to
#
# two
#
# days
#
# per
#
# week,
#
# unless
#
# a
#
# different
#
# schedule
#
# is
#
# agreed
#
# upon
#
# with
#
# management.
#
# ●
#
# Equipment
#
# &
#
# Connectivity:
#
# The
#
# company
#
# provides
#
# necessary
#
# hardware
#
# support.
#
# Employees
#
# must
#
# ensure
#
# they
#
# have
#
# a
#
# reliable
#
# internet
#
# connection
#
# and
#
# adhere
#
# to
#
# data
#
# security
#
# policies
#
# while
#
# working
#
# remotely.
#
# Section
#
# 3:
#
# Expense
#
# Reimbursement
#
# ●
#
# Business
#
# Expenses:
#
# Employees
#
# must
#
# submit
#
# receipts
#
# and
#
# supporting
#
# documentation
#
# within
#
# 30
#
# days
#
# of
#
# incurring
#
# the
#
# expense.
#
# ●
#
# Eligible
#
# Expenses:
#
# Includes
#
# travel,
#
# meals,
#
# accommodation,
#
# and
#
# approved
#
# business-related
#
# expenditures.
#
# ●
#
# Submission
#
# Process:
#
# Expense
#
# claims
#
# should
#
# be
#
# submitted
#
# through
#
# the
#
# online
#
# portal.
#
# Reimbursements
#
# are
#
# processed
#
# within
#
# 14
#
# business
#
# days
#
# upon
#
# approval.
#
# Section
#
# 4:
#
# Employee
#
# Benefits
#
# ●
#
# Health
#
# Insurance:
#
# Full-time
#
# employees
#
# receive
#
# comprehensive
#
# health
#
# insurance
#
# coverage
#
# that
#
# includes
#
# medical,
#
# dental,
#
# and
#
# vision
#
# care.
#
# ●
#
# Retirement
#
# Plans:
#
# The
#
# company
#
# offers
#
# a
#
# 401(k)
#
# plan
#
# with
#
# matching
#
# contributions
#
# of
#
# up
#
# to
#
# 5%
#
# of
#
# the
#
# employee’s
#
# salary.
#
# ●
#
# Wellness
#
# Programs:
#
# Employees
#
# have
#
# access
#
# to
#
# wellness
#
# programs
#
# including
#
# fitness
#
# memberships,
#
# health
#
# screenings,
#
# and
#
# stress
#
# management
#
# workshops.
#
# Additional
#
# Information:
#
#
# For
#
# more
#
# detailed
#
# information
#
# or
#
# any
#
# policy
#
# updates,
#
# please
#
# refer
#
# to
#
# the
#
# complete
#
# HR
#
# Policy
#
# Manual
#
# available
#
# on
#
# the
#
# company
#
# intranet
#
# or
#
# contact
#
# the
#
# HR
#
# department
#
# directly.

# %%
import os
from dotenv import load_dotenv
#$os.environ['OPENAI_API_KEY']=os.getenv('OPENAI_API_KEY')
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('proservartner_HR_example.pdf')
docs=loader.load()
docs
# Out:
# [Document(page_content='HR  Policy  Document  –  Employee  Guidelines  \nSection  1:  Leave  Policies  \n●  Sick  Leave:  All  full-time  employees  are  entitled  to  12  paid  sick  days  per  calendar  year.  ●  Vacation  Leave:  Employees  are  granted  15  vacation  days  per  year,  subject  to  prior  \nmanagerial\n \napproval.\n ●  Personal  Leave:  Up  to  3  personal  days  may  be  taken  for  emergencies  or  special  \noccasions.\n \nDocumentation\n \nmay\n \nbe\n \nrequired.\n \nSection  2:  Work-from-Home  Guidelines  \n●  Eligibility:  Employees  who  have  completed  at  least  6  months  of  service  are  eligible  for  \nremote\n \nwork.\n ●  Schedule:  Remote  work  is  permitted  up  to  two  days  per  week,  unless  a  different  \nschedule\n \nis\n \nagreed\n \nupon\n \nwith\n \nmanagement.\n ●  Equipment  &  Connectivity:  The  company  provides  necessary  hardware  support.  \nEmployees\n \nmust\n \nensure\n \nthey\n \nhave\n \na\n \nreliable\n \ninternet\n \nconnection\n \nand\n \nadhere\n \nto\n \ndata\n \nsecurity\n \npolicies\n \nwhile\n \nworking\n \nremotely.\n \nSection  3:  Expense  Reimbursement  \n●  Business  Expenses:  Employees  must  submit  receipts  and  supporting  documentation  \nwithin\n \n30\n \ndays\n \nof\n \nincurring\n \nthe\n \nexpense.\n ●  Eligible  Expenses:  Includes  travel,  meals,  accommodation,  and  approved  \nbusiness-related\n \nexpenditures.\n ●  Submission  Process:  Expense  claims  should  be  submitted  through  the  online  portal.  \nReimbursements\n \nare\n \nprocessed\n \nwithin\n \n14\n \nbusiness\n \ndays\n \nupon\n \napproval.\n \nSection  4:  Employee  Benefits  \n●  Health  Insurance:  Full-time  employees  receive  comprehensive  health  insurance  \ncoverage\n \nthat\n \nincludes\n \nmedical,\n \ndental,\n \nand\n \nvision\n \ncare.\n ●  Retirement  Plans:  The  company  offers  a  401(k)  plan  with  matching  contributions  of  up  \nto\n \n5%\n \nof\n \nthe\n \nemployee’s\n \nsalary.\n ●  Wellness  Programs:  Employees  have  access  to  wellness  programs  including  fitness  \nmemberships,\n \nhealth\n \nscreenings,\n \nand\n \nstress\n \nmanagement\n \nworkshops.\n \nAdditional  Information:  \n \nFor\n \nmore\n \ndetailed\n \ninformation\n \nor\n \nany\n \npolicy\n \nupdates,\n \nplease\n \nrefer\n \nto\n \nthe\n \ncomplete\n \nHR\n \nPolicy\n \nManual\n \navailable\n \non\n \nthe\n \ncompany\n \nintranet\n \nor\n \ncontact\n \nthe\n \nHR\n \ndepartment\n \ndirectly.\n \n ', metadata={'source': 'proservartner_HR_example.pdf', 'page': 0})]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
text_splitter=text_splitter.split_documents(docs)
